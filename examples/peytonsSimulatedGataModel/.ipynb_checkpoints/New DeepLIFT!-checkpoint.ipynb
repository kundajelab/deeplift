# %%
# %matplotlib inline
from __future__ import division;
from __future__ import print_function;
from __future__ import absolute_import;
import sys, os;
from collections import OrderedDict, namedtuple;
import numpy as np;
import theano

#Import some general util stuff
scriptsDir = os.environ.get("UTIL_SCRIPTS_DIR");
if (scriptsDir is None):
    raise Exception("Please set environment variable UTIL_SCRIPTS_DIR to point to av_scripts");
sys.path.insert(0,scriptsDir);
import pathSetter;
import util;
import fileProcessing as fp
from plottingUtilitiesPackage import matplotlibHelpers as mplh;

#import deepLIFT stuff
scriptsDir = os.environ.get("ENHANCER_SCRIPTS_DIR");
if (scriptsDir is None):
    raise Exception("Please set environment variable ENHANCER_SCRIPTS_DIR to point to enhancer_prediction_code");
sys.path.insert(0,scriptsDir+"/featureSelector/deepLIFFT/");
import criticalSubsetIdentification as csi
import deepLIFTutils
sys.path.insert(0,scriptsDir+"/featureSelector/deepLIFFT/kerasBasedBackprop");
from deepLIFTonGPU import ScoreTypes, Activations_enum, OutLayerInfo, getScoreFunc
sys.path.insert(0,scriptsDir+"/featureSelector/deepLIFFT/generalised_deeplift");

#Make sure the directory is set to import the lab's version of keras
scriptsDir = os.environ.get("KERAS_DIR");
if (scriptsDir is None):
    raise Exception("Please set environment variable KERAS_DIR");
sys.path.insert(0,scriptsDir)

# %%
#Load the keras model, make sure you normalise the weights
#of the first convolutional layer to be mean-centered at each position.
modelWeights = "apr11_deltaDeepLift_3task_2motif_deptask2_samplepwm_numSeq_20000_peakSize_200_DNNSimModel_20filt_15bp_plst50_200fc_do_epoch_42_modelWeights.h5"
modelYaml = "apr11_deltaDeepLift_3task_2motif_deptask2_samplepwm_numSeq_20000_peakSize_200_DNNSimModel_20filt_15bp_plst50_200fc_do_epoch_42_modelYaml.yaml"
model = deepLIFTutils.loadKerasModel(modelWeights, modelYaml)
reload(deepLIFTutils);
deepLIFTutils.meanNormaliseFirstConvLayerWeights(model);

# %%
from importDataPackage import importData
reload(importData)
trainData, validData, testData = importData.loadTrainTestValidFromYaml("yaml/features.yaml","yaml/labels.yaml", "yaml/splits.yaml")
# Out:
# Processed 10000 lines of apr10_deltaDeepLift_3task_2motif_deptask2_numSeq_20000_peakSize_200_TAL1_known1_GATA_known4_numSeq_20000_peakSize_200_freqMoMean_2_w_SPI1_known4_AP1_disc3_joint.fa.gz
# Processed 20000 lines of apr10_deltaDeepLift_3task_2motif_deptask2_numSeq_20000_peakSize_200_TAL1_known1_GATA_known4_numSeq_20000_peakSize_200_freqMoMean_2_w_SPI1_known4_AP1_disc3_joint.fa.gz
# ('WARNING.', 'cls2_6001', 'was not found in train/test/valid splits')
# This is the only time such a warning will be printed. Remaining such ids will be silently ignored
# Processed 30000 lines of apr10_deltaDeepLift_3task_2motif_deptask2_numSeq_20000_peakSize_200_TAL1_known1_GATA_known4_numSeq_20000_peakSize_200_freqMoMean_2_w_SPI1_known4_AP1_disc3_joint.fa.gz
# Processed 40000 lines of apr10_deltaDeepLift_3task_2motif_deptask2_numSeq_20000_peakSize_200_TAL1_known1_GATA_known4_numSeq_20000_peakSize_200_freqMoMean_2_w_SPI1_known4_AP1_disc3_joint.fa.gz
# ...

# %%
import deepLIFTutils
reload(deepLIFTutils)
from importDataPackage import importData
reload(importData)
data = testData

# %%
import generalised_deeplift_util as genrdl_util
reload(genrdl_util)
import generalised_deeplift
reload(generalised_deeplift)
import keras_conversion as kc
reload(kc)
import backend
reload(backend)
#convert the keras sequential model into a series of DeepLIFT layers
convertedLayers = kc.convert_sequential_model(model)

# %%
#specify the task
convertedLayers[-1].set_target_node(2)
#compute the multipliers for the task
convertedLayers[0].update_mxts()

# %%
#Compile the function to get the contributions of the input layer, given the activations of the input layer
#[convertedLayers[0].get_activation_vars()] are the inputs to the theano function,
#convertedLayers[0].get_target_contrib_vars() is the output
contribFunc = theano.function([convertedLayers[0].get_activation_vars()],
                              convertedLayers[0].get_target_contrib_vars(),
                                allow_input_downcast=True)

# %%
#run the function above on the training data
contribs_trainData = np.array(genrdl_util.run_function_in_batches(contribFunc, input_data_list=[trainData.X], progress_update=10000))
# Out:
# Done 0
# Done 10000
# Done 20000

# %%
#OLD DEEP LIFT
trackLayers = [0]
outputLayers = [OutLayerInfo(outLayNoAct=model.layers[-2],activation='sigmoid')]
import deepLIFTonGPU
reload(deepLIFTonGPU)
scoreFunc = deepLIFTonGPU.getScoreFunc(model, trackLayers, outputLayers, 
                          [ScoreTypes.deepLIFT_rawContrib, ScoreTypes.sensitivity]);
reload(deepLIFTutils)
dlOnData = deepLIFTutils.runScoreFuncOnData(batchSize=10
                                                          , data=trainData.X
                                                          , scoreFunc=scoreFunc
                                                          , progressUpdate=10000)
trackLayerIdx = 0
outputLayerIdx = 0
neuronOfInterest_idx = 2
dLRawContribs_singleNeuron = dlOnData[ScoreTypes.deepLIFT_rawContrib]\
                                                    [outputLayerIdx]\
                                                    [trackLayerIdx]\
                                                    [neuronOfInterest_idx];
# Out:
# Data needs to be a list, one per input mode. Wrapping for you
# ('On', 0)
# ('On', 10000)
# ('On', 20000)

# %%
idx = 19643
print(model.layers[-2].get_weights()[1])
# Out:
# [ 0.01786226  0.04705779 -0.02361147]

# %%
weirdOne = trainData.X[idx]
deepLIFTutils.makePngOfSequenceDeepLIFTScores(dLRawContribs_singleNeuron[idx]
                                    , pngName="sequenceDLscores_weirdOne_"+str(idx)+".png"
                                    , plotConvPath="plotConvFilter.R")
# Out:
# The plotConvPath argument is deprecated; no longer needed
# ('Saving', 'sequenceDLscores_weirdOne_19643.png')

# %%
deepLIFTutils.makePngOfSequenceDeepLIFTScores(contribs_trainData[idx]
                                    , pngName="new_sequenceDLscores_weirdOne_"+str(idx)+".png"
                                    , plotConvPath="plotConvFilter.R")
# Out:
# The plotConvPath argument is deprecated; no longer needed
# ('Saving', 'new_sequenceDLscores_weirdOne_19643.png')

# %%
mutatedWeirdOne = weirdOne.copy()
mutatedWeirdOne[:,:,123:136] = 0
print(mutatedWeirdOne.shape)
mutatedWeirdOneDL = deepLIFTutils.runScoreFuncOnData(batchSize=1, data=np.array([mutatedWeirdOne]), scoreFunc=scoreFunc, progressUpdate=1)
# Out:
# (1, 4, 200)
# Data needs to be a list, one per input mode. Wrapping for you
# ('On', 0)

# %%
deepLIFTutils.makePngOfSequenceDeepLIFTScores(mutatedWeirdOneDL[ScoreTypes.deepLIFT_rawContrib][outputLayerIdx][trackLayerIdx][neuronOfInterest_idx][0]
                                    , pngName="sequenceDLscores_weirdOne_gataSilenced_"+str(idx)+".png"
                                    , plotConvPath="plotConvFilter.R")
# Out:
# The plotConvPath argument is deprecated; no longer needed
# ('Saving', 'sequenceDLscores_weirdOne_gataSilenced_19643.png')

# %%
mutatedWeirdOneDL = genrdl_util.run_function_in_batches(contribFunc, input_data_list=[np.array([mutatedWeirdOne])])[0]
deepLIFTutils.makePngOfSequenceDeepLIFTScores(mutatedWeirdOneDL
                                    , pngName="new_sequenceDLscores_weirdOne_gataSilenced_"+str(idx)+".png"
                                    , plotConvPath="plotConvFilter.R")
# Out:
# Done 0
# The plotConvPath argument is deprecated; no longer needed
# ('Saving', 'new_sequenceDLscores_weirdOne_gataSilenced_19643.png')
